# %%
import os
import pandas as pd

from src.constants import *

# %%
with open(os.path.join(ARTICLES_PATH, "33555423", "entities.csv"), "r") as f:
    entities_df = pd.read_csv(f).drop('Unnamed: 0', axis=1)

# %%
entities_df
# Out:
#                        Word    Type       CUI  Document  StartChar  EndChar  \
# 0       anastomotic leakage    DISO  C0919691  33555423          0       19
# 1                        AL    DISO  C0919691  33555423         21       23
# 2              complication    DISO  C0009566  33555423         56       69
# 3        colorectal surgery    OCCU  C0009369  33555423         76       94
# 4                    affect    CONC  C0392760  33555423         96      105
# ...                     ...     ...       ...       ...        ...      ...
# 1328   level of anastomosis    PROC  C0677554  33555423      21794    21814
# 1329  height of anastomosis    PROC  C0677554  33555423      21816    21837
# 1330                compare  ENTITY     UNDEF  33555423      21842    21851
# 1331              hand-sewn  ENTITY     UNDEF  33555423      21852    21861
# 1332     staple anastomosis  ENTITY     UNDEF  33555423      21866    21885
#
#       StartWord  EndWord  Sentence
# ...

# %%
len(entities_df["Type"].value_counts())
# Out:
# 21

# %%
entities_df["Type"].value_counts()
# Out:
# CONC        486
# CARDINAL    149
# DISO        141
# PROC        134
# ENTITY      103
# PERCENT      92
# CHEM         45
# LIVB         40
# ORG          24
# ACTI         21
# OBJC         17
# OCCU         17
# DATE         14
# ANAT         13
# PHEN         10
# PHYS          9
# GEOG          7
# PERSON        5
# PRODUCT       4
# ORDINAL       1
# NORP          1
# Name: Type, dtype: int64
